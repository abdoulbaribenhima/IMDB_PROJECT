# %% [markdown]
# ![title](./Sogeti-Logo.wine.png)

# %% [markdown]
# <div class="alert alert-info">
#     <h1><strong> Sogeti test Data-science :</strong></h1>
# </div>

# %%
#importation de librairies
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"./IMDB-Movie-Data.csv")
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0

# %%
df = df.drop('Rank', axis='columns')

# %%
df.describe()
# Out:
#               Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean   2012.783000         113.172000     6.723200  1.698083e+05
# std       3.205962          18.810908     0.945429  1.887626e+05
# min    2006.000000          66.000000     1.900000  6.100000e+01
# 25%    2010.000000         100.000000     6.200000  3.630900e+04
# 50%    2014.000000         111.000000     6.800000  1.107990e+05
# 75%    2016.000000         123.000000     7.400000  2.399098e+05
# max    2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
# En remarque déjà la moyenne du Rating utilisant discribe function qui est de 6.723

# %%
df.shape #aficher la forme du df avant d'illiminer les valeurs null
# Out:
# (1000, 11)

# %%
df.isnull().mean() # les colonnes ayant des val nulls
# Out:
# Title                 0.000
# Genre                 0.000
# Description           0.000
# Director              0.000
# Actors                0.000
# Year                  0.000
# Runtime (Minutes)     0.000
# Rating                0.000
# Votes                 0.000
# Revenue (Millions)    0.128
# Metascore             0.064
# dtype: float64

# %%
df.dropna(inplace=True)## éliminer les variable null

# %%
df.isnull().mean()
# Out:
# Title                 0.0
# Genre                 0.0
# Description           0.0
# Director              0.0
# Actors                0.0
# Year                  0.0
# Runtime (Minutes)     0.0
# Rating                0.0
# Votes                 0.0
# Revenue (Millions)    0.0
# Metascore             0.0
# dtype: float64

# %%
df.shape
# Out:
# (838, 11)

# %%
df.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_af9ce_row0_col5, #T_af9ce_row31_col5, #T_af9ce_row44_col5, #T_af9ce_row45_col10, #T_af9ce_row55_col5, #T_af9ce_row72_col5, #T_af9ce_row96_col5, #T_af9ce_row106_col5, #T_af9ce_row110_col5, #T_af9ce_row115_col5, #T_af9ce_row117_col5, #T_af9ce_row123_col10, #T_af9ce_row136_col10, #T_af9ce_row143_col5, #T_af9ce_row151_col5, #T_af9ce_row156_col5, #T_af9ce_row174_col5, #T_af9ce_row176_col5, #T_af9ce_row190_col5, #T_af9ce_row195_col5, #T_af9ce_row199_col10, #T_af9ce_row201_col5, #T_af9ce_row210_col5, #T_af9ce_row212_col5, #T_af9ce_row225_col5, #T_af9ce_row232_col5, #T_af9ce_row234_col5, #T_af9ce_row246_col5, #T_af9ce_row253_col5, #T_af9ce_row267_col5, #T_af9ce_row272_col5, #T_af9ce_row278_col5, #T_af9ce_row279_col5, #T_af9ce_row296_col5, #T_af9ce_row301_col5, #T_af9ce_row302_col5, #T_af9ce_row317_col5, #T_af9ce_row318_col5, #T_af9ce_row322_col5, #T_af9ce_row331_col5, #T_af9ce_row337_col10, #T_af9ce_row339_col5, #T_af9ce_row340_col5, #T_af9ce_row343_
{
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_af9ce_row1_col7, #T_af9ce_row8_col7, #T_af9ce_row49_col7, #T_af9ce_row74_col7, #T_af9ce_row80_col7, #T_af9ce_row89_col7, #T_af9ce_row90_col7, #T_af9ce_row138_col7, #T_af9ce_row142_col7, #T_af9ce_row157_col7, #T_af9ce_row162_col7, #T_af9ce_row188_col7, #T_af9ce_row197_col7, #T_af9ce_row198_col7, #T_af9ce_row201_col7, #T_af9ce_row235_col7, #T_af9ce_row245_col7, #T_af9ce_row248_col7, #T_af9ce_row252_col7, #T_af9ce_row269_col7, #T_af9ce_row281_col7, #T_af9ce_row293_col7, #T_af9ce_row328_col7, #T_af9ce_row382_col7, #T_af9ce_row395_col7, #T_af9ce_row396_col7, #T_af9ce_row431_col7, #T_af9ce_row458_col7, #T_af9ce_row468_col7, #T_af9ce_row529_col7, #T_af9ce_row549_col7, #T_af9ce_row550_col7, #T_af9ce_row563_col7, #T_af9ce_row568_col7, #T_af9ce_row602_col7, #T_af9ce_row630_col7, #T_af9ce_row683_col7, #T_af9ce_row694_col7, #T_af9ce_row702_col7, #T_af9ce_row742_col7, #T_af9ce_row744_col7, #T_af9ce_row813_col7, #T_af9ce_row823_col7 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_af9ce_row1_col8, #T_af9ce_row37_col6, #T_af9ce_row98_col8, #T_af9ce_row182_col6, #T_af9ce_row206_col10, #T_af9ce_row210_col6, #T_af9ce_row211_col10, #T_af9ce_row237_col6, #T_af9ce_row276_col9, #T_af9ce_row279_col9, #T_af9ce_row308_col10, #T_af9ce_row335_col6, #T_af9ce_row339_col10, #T_af9ce_row364_col6, #T_af9ce_row373_col10, #T_af9ce_row376_col6, #T_af9ce_row377_col8, #T_af9ce_row508_col10, #T_af9ce_row593_col10, #T_af9ce_row609_col10, #T_af9ce_row638_col6, #T_af9ce_row644_col6, #T_af9ce_row665_col10, #T_af9ce_row699_col6, #T_af9ce_row737_col6, #T_af9ce_row748_col6, #T_af9ce_row798_col10 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_af9ce_row1_col9, #T_af9ce_row42_col10, #T_af9ce_row50_col9, #T_af9ce_row53_col8, #T_af9ce_row62_col10, #T_af9ce_row95_col9, #T_af9ce_row115_col9, #T_af9ce_row122_col9, #T_af9ce_row136_col8, #T_af9ce_row175_col9, #T_af9ce_row264_col9, #T_af9ce_row268_col9, #T_af9ce_row301_col9, #T_af9ce_ro

# %% [markdown]
# <div class="alert alert-warning">
#   <h2><strong> QUESTIONS: </strong></h2>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <strong>
#
# 1. Calculer la moyenne des notes au global (colonne `rating`).
# 2. Calculer la moyenne des notes par réalisateur (colonne `rating`). ainsi que le total au box-office (colonne `Revenue (Millions)`) en une instruction Pandas et sauvegarder le résultat en CSV.
# 3. A l'aide [des données d'inflation de l'OCDE](https://data.oecd.org/price/inflation-cpi.htm) créer une nouvelle colonne incluant les revenus en dollars constant (la base 100 étant l'année du film le plus ancien dans le jeu de données) et sauvegarder le résultat en CSV.
# 4. Créer un graphique avec la moyenne des notes (colonne `rating`) des films en ordonnée et leur année en abscisse et sauvegarder le résultat en JPEG.
# 5. Déterminer les paramètres les plus impactants sur le score (colonne `rating`).
#
#     </strong>
# </div>

# %% [markdown]
# ## Q1: Calcule de la moyenne des notes au global (colonne rating).

# %%
mean_df = df['Rating'].mean()
print("La moyenne des notes au global est :","%.2f" % mean_df)## limitter les flottant à deux décimales
# Out:
# La moyenne des notes au global est : 6.81

# %% [markdown]
# ## Q2: Calcule de la moyenne des notes par réalisateur (colonne rating)

# %%
dire = df.groupby(['Director'])["Rating"]# grouper les notes par réalisateur
dire.count()
# Out:
# Director
# Aamir Khan             1
# Abdellatif Kechiche    1
# Adam McKay             4
# Adam Shankman          2
# Adam Wingard           2
#                       ..
# Xavier Dolan           1
# Yimou Zhang            1
# Yorgos Lanthimos       2
# Zack Snyder            5
# Zackary Adler          1
# Name: Rating, Length: 524, dtype: int64

# %%
real = df.groupby(['Director'])['Rating'].mean().to_frame()# grouper la moyenne des notes par réalisateur
real.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_7d780_row0_col0, #T_7d780_row154_col0 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_7d780_row1_col0, #T_7d780_row16_col0, #T_7d780_row89_col0, #T_7d780_row134_col0, #T_7d780_row170_col0, #T_7d780_row172_col0, #T_7d780_row177_col0, #T_7d780_row205_col0, #T_7d780_row261_col0, #T_7d780_row271_col0, #T_7d780_row325_col0, #T_7d780_row364_col0, #T_7d780_row371_col0, #T_7d780_row412_col0, #T_7d780_row413_col0, #T_7d780_row489_col0 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_7d780_row2_col0, #T_7d780_row19_col0, #T_7d780_row23_col0, #T_7d780_row37_col0, #T_7d780_row58_col0, #T_7d780_row92_col0, #T_7d780_row123_col0, #T_7d780_row136_col0, #T_7d780_row138_col0, #T_7d780_row171_col0, #T_7d780_row178_col0, #T_7d780_row230_col0, #T_7d780_row276_col0, #T_7d780_row310_col0, #T_7d780_row370_col0, #T_7d780_row383_col0, #T_7d780_row425_col0 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_7d780_row3_col0, #T_7d780_row21_col0, #T_7d780_row22_col0, #T_7d780_row39_col0, #T_7d780_row86_col0, #T_7d780_row116_col0, #T_7d780_row148_col0, #T_7d780_row168_col0, #T_7d780_row181_col0, #T_7d780_row183_col0, #T_7d780_row202_col0, #T_7d780_row215_col0, #T_7d780_row245_col0, #T_7d780_row262_col0, #T_7d780_row354_col0, #T_7d780_row376_col0, #T_7d780_row381_col0, #T_7d780_row395_col0, #T_7d780_row411_col0, #T_7d780_row419_col0, #T_7d780_row456_col0, #T_7d780_row476_col0, #T_7d780_row509_col0 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_7d780_row4_col0, #T_7d780_row43_col0, #T_7d780_row93_col0, #T_7d780_row186_col0, #T_7d780_row283_col0, #T_7d780_row287_col0, #T_7d780_row294_col0, #T_7d780_row319_col0, #T_7d780_row384_col0, #T_7d780_row475_col0 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_7d780_row5_col0, #T_7d780_row160_col0, #T_7d780_row173_col0, #T_7d780_row195_col0, #T_7d780_row209_col0, #T_7d780_row256_col0, #T_7d780_row281_col0, #T_7d780_row302_col0, #T_7d780_row344_col0, #T_7d780_row347_col0, #T_7d780_row372_col0, #T_7d780_row458_col0, #T_7d780_row461_col0, #T_7d780_row470_col0, #T_7d780_row492_col0, #T_7d780_row493_col0, #T_7d780_row506_col0 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_7d780_row6_col0, #T_7d780_row176_col0, #T_7d780_row221_col0, #T_7d780_row306_col0, #T_7d780_row351_col0 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_7d780_row7_col0, #T_7d780_row71_col0, #T_7d780_row79_col0, #T_7d780_row121_col0, #T_7d780_row193_col0, #T_7d780_row212_col0, #T_7d780_row225_col0, #T_7d780_row237_col0, #T_7d780_row257_col0, #T_7d780_row270_col0, #T_7d780_row298_col0, #T_7d780_row375_col0, #T_7d780_row389_col0, #T_7d780_row454_col0, #T_7d780_row469_col0, #T_7d780_row478_col0 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_7d780_row8_col0, #T_7d780_row28_col0, #T_7d780_row81_col0, #T_7d780_row122_col0, #T_7d780_row146_col0, #T_7d780_row206_col0, #T_7d780_row260_col0, #T_7d780_row358_col0, #T_7d780_row473_col0 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_7d780_row9_col0, #T_7d780_row128_col0 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_7d780_row10_col0, #T_7d780_row17_col0, #T_7d780_row30_col0, #T_7d780_row75_col0, #T_7d780_row85_col0, #T_7d780_row87_col0, #T_7d780_row104_col0, #T_7d780_row157_col0, #T_7d780_row162_col0, #T_7d780_row167_col0, #T_7d780_row184_col0, #T_7d780_row185_col0, #T_7d780_row214_col0, #T_7d780_row224_col0, #T_7d780_row266_col0, #T_7d780_row304_col0, #T_7d780_row324_col0, #T_7d780_row430_col0, #T_7d780_row434_col0, #T_7d780_row445_col0, #T_7d780_row451_col0, #T_7d780_row485_col0, #T_7d780_row496_col0, #T_7d780_row521_col0 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_7d780_row11_col0, #T_7d780_row66_col0, #T_7d780_row111_col0, #T_7d780_row118_col0, #T_7d780_row188_col0, #T_7d780_row192_col0, #T_7d780_row210_col0, #T_7d780_row241_col0 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_7d780_row12_col0, #T_7d780_row161_col0, #T_7d780_row169_col0, #T_7d780_row397_col0, #T_7d780_row453_col0 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_7d780_row13_col0, #T_7d780_row59_col0, #T_7d780_row65_col0, #T_7d780_row103_col0, #T_7d780_row131_col0, #T_7d780_row132_col0, #T_7d780_row174_col0, #T_7d780_row251_col0, #T_7d780_row264_col0, #T_7d780_row267_col0, #T_7d780_row303_col0, #T_7d780_row353_col0, #T_7d780_row382_col0, #T_7d780_row416_col0, #T_7d780_row440_col0, #T_7d780_row457_col0, #T_7d780_row460_col0, #T_7d780_row483_col0, #T_7d780_row502_col0, #T_7d780_row511_col0 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_7d780_row14_col0 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_7d780_row15_col0, #T_7d780_row35_col0, #T_7d780_row163_col0 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_7d780_row18_col0, #T_7d780_row52_col0, #T_7d780_row56_col0, #T_7d780_row83_col0, #T_7d780_row94_col0, #T_7d780_row115_col0, #T_7d780_row117_col0, #T_7d780_row182_col0, #T_7d780_row228_col0, #T_7d780_row236_col0, #T_7d780_row243_col0, #T_7d780_row246_col0, #T_7d780_row284_col0, #T_7d780_row320_col0, #T_7d780_row330_col0, #T_7d780_row342_col0, #T_7d780_row352_col0, #T_7d780_row380_col0, #T_7d780_row401_col0, #T_7d780_row405_col0, #T_7d780_row407_col0, #T_7d780_row422_col0, #T_7d780_row436_col0, #T_7d780_row482_col0, #T_7d780_row487_col0, #T_7d780_row507_col0 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_7d780_row20_col0, #T_7d780_row45_col0, #T_7d780_row77_col0, #T_7d780_row95_col0, #T_7d780_row159_col0, #T_7d780_row194_col0, #T_7d780_row220_col0, #T_7d780_row232_col0, #T_7d780_row279_col0, #T_7d780_row288_col0, #T_7d780_row296_col0, #T_7d780_row316_col0, #T_7d780_row427_col0, #T_7d780_row443_col0, #T_7d780_row498_col0 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_7d780_row24_col0, #T_7d780_row91_col0 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_7d780_row25_col0, #T_7d780_row31_col0, #T_7d780_row34_col0, #T_7d780_row55_col0, #T_7d780_row67_col0, #T_7d780_row196_col0, #T_7d780_row204_col0, #T_7d780_row258_col0, #T_7d780_row275_col0, #T_7d780_row285_col0, #T_7d780_row337_col0, #T_7d780_row345_col0, #T_7d780_row350_col0, #T_7d780_row374_col0, #T_7d780_row450_col0, #T_7d780_row495_col0, #T_7d780_row499_col0, #T_7d780_row514_col0 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_7d780_row26_col0, #T_7d780_row113_col0, #T_7d780_row125_col0, #T_7d780_row222_col0, #T_7d780_row231_col0, #T_7d780_row238_col0, #T_7d780_row297_col0, #T_7d780_row300_col0, #T_7d780_row313_col0, #T_7d780_row335_col0, #T_7d780_row361_col0, #T_7d780_row362_col0, #T_7d780_row366_col0, #T_7d780_row373_col0, #T_7d780_row403_col0, #T_7d780_row464_col0, #T_7d780_row465_col0 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_7d780_row27_col0, #T_7d780_row54_col0, #T_7d780_row73_col0, #T_7d780_row197_col0, #T_7d780_row328_col0, #T_7d780_row448_col0 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_7d780_row29_col0, #T_7d780_row44_col0, #T_7d780_row60_col0, #T_7d780_row101_col0, #T_7d780_row207_col0, #T_7d780_row211_col0, #T_7d780_row234_col0, #T_7d780_row239_col0, #T_7d780_row268_col0, #T_7d780_row292_col0, #T_7d780_row340_col0, #T_7d780_row348_col0, #T_7d780_row363_col0, #T_7d780_row394_col0, #T_7d780_row439_col0, #T_7d780_row474_col0, #T_7d780_row505_col0 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_7d780_row32_col0, #T_7d780_row42_col0, #T_7d780_row57_col0, #T_7d780_row145_col0, #T_7d780_row217_col0, #T_7d780_row229_col0, #T_7d780_row272_col0, #T_7d780_row315_col0, #T_7d780_row317_col0, #T_7d780_row471_col0 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_7d780_row33_col0, #T_7d780_row40_col0, #T_7d780_row80_col0, #T_7d780_row135_col0, #T_7d780_row151_col0, #T_7d780_row180_col0, #T_7d780_row191_col0, #T_7d780_row219_col0, #T_7d780_row226_col0, #T_7d780_row254_col0, #T_7d780_row263_col0, #T_7d780_row269_col0, #T_7d780_row349_col0, #T_7d780_row355_col0, #T_7d780_row357_col0, #T_7d780_row386_col0, #T_7d780_row433_col0, #T_7d780_row463_col0 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_7d780_row36_col0, #T_7d780_row522_col0 {
#   backgro

# %% [markdown]
# ## Calcule du total au box-office par réalisateur (colonne Revenue (Millions))

# %%
box = df.groupby(['Director'])['Revenue (Millions)'].sum().to_frame()#grouper la somme des revenues par réalisateur
box.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_8f63b_row0_col0, #T_8f63b_row1_col0, #T_8f63b_row8_col0, #T_8f63b_row18_col0, #T_8f63b_row19_col0, #T_8f63b_row20_col0, #T_8f63b_row21_col0, #T_8f63b_row26_col0, #T_8f63b_row27_col0, #T_8f63b_row31_col0, #T_8f63b_row34_col0, #T_8f63b_row37_col0, #T_8f63b_row41_col0, #T_8f63b_row51_col0, #T_8f63b_row52_col0, #T_8f63b_row55_col0, #T_8f63b_row66_col0, #T_8f63b_row76_col0, #T_8f63b_row79_col0, #T_8f63b_row86_col0, #T_8f63b_row89_col0, #T_8f63b_row95_col0, #T_8f63b_row98_col0, #T_8f63b_row101_col0, #T_8f63b_row105_col0, #T_8f63b_row108_col0, #T_8f63b_row122_col0, #T_8f63b_row123_col0, #T_8f63b_row137_col0, #T_8f63b_row142_col0, #T_8f63b_row145_col0, #T_8f63b_row146_col0, #T_8f63b_row148_col0, #T_8f63b_row159_col0, #T_8f63b_row160_col0, #T_8f63b_row170_col0, #T_8f63b_row177_col0, #T_8f63b_row186_col0, #T_8f63b_row188_col0, #T_8f63b_row193_col0, #T_8f63b_row194_col0, #T_8f63b_row199_col0, #T_8f63b_row212_col0, #T_8f63b_row214_col0, #T_8f63b_row215_col0, #T_8f63b_row224_col0, #T_8f63b_row227_col0, #T_8f63b_row228_col0, #T_8f63b_row229_col0, #T_8f63b_row230_col0, #T_8f63b_row232_col0, #T_8f63b_row233_col0, #T_8f63b_row234_col0, #T_8f63b_row247_col
col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_8f63b_row22_col0, #T_8f63b_row43_col0, #T_8f63b_row49_col0, #T_8f63b_row206_col0, #T_8f63b_row245_col0, #T_8f63b_row261_col0, #T_8f63b_row300_col0, #T_8f63b_row322_col0, #T_8f63b_row354_col0, #T_8f63b_row358_col0, #T_8f63b_row361_col0, #T_8f63b_row383_col0, #T_8f63b_row447_col0, #T_8f63b_row462_col0, #T_8f63b_row472_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_8f63b_row23_col0 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_8f63b_row29_col0, #T_8f63b_row292_col0, #T_8f63b_row512_col0 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_8f63b_row30_col0, #T_8f63b_row258_col0, #T_8f63b_row328_col0, #T_8f63b_row339_col0, #T_8f63b_row454_col0, #T_8f63b_row506_col0 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_8f63b_row33_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_8f63b_row35_col0 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_8f63b_row36_col0, #T_8f63b_row127_col0 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_8f63b_row38_col0, #T_8f63b_row57_col0, #T_8f63b_row81_col0, #T_8f63b_row102_col0, #T_8f63b_row120_col0, #T_8f63b_row184_col0, #T_8f63b_row191_col0, #T_8f63b_row197_col0, #T_8f63b_row201_col0, #T_8f63b_row210_col0, #T_8f63b_row250_col0, #T_8f63b_row293_col0, #T_8f63b_row294_col0, #T_8f63b_row370_col0, #T_8f63b_row385_col0, #T_8f63b_row460_col0, #T_8f63b_row504_col0, #T_8f63b_row514_col0, #T_8f63b_row517_col0 {
#   background-color: #fff2eb;

# %%
## les top 10 réalisateur niveau revenue
top10 = box.sort_values(["Revenue (Millions)"], ascending=False).head(10)
top10.style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_10c1f_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_10c1f_row1_col0 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_10c1f_row2_col0 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_10c1f_row3_col0 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_10c1f_row4_col0 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_10c1f_row5_col0 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_10c1f_row6_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_10c1f_row7_col0 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_10c1f_row8_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_10c1f_row9_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_10c1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Revenue (Millions)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Director</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10c1f_level0_row0" class="row_heading level0 row0" >J.J. Abrams</th>
#       <td id="T_10c1f_row0_col0" class="data row0 col0" >1683.450000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row1" class="row_heading level0 row1" >David Yates</th>
#       <td id="T_10c1f_row1_col0" class="data row1 col0" >1630.510000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row2" class="row_heading level0 row2" >Christopher Nolan</th>
#       <td id="T_10c1f_row2_col0" class="data row2 col0" >1515.090000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row3" class="row_heading level0 row3" >Michael Bay</th>
#       <td id="T_10c1f_row3_col0" class="data row3 col0" >1421.320000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row4" class="row_heading level0 row4" >Francis Lawrence</th>
#       <td id="T_10c1f_row4_col0" class="data row4 col0" >1299.810000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row5" class="row_heading level0 row5" >Joss Whedon</th>
#       <td id="T_10c1f_row5_col0" class="data row5 col0" >1082.270000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row6" class="row_heading level0 row6" >Jon Favreau</th>
#       <td id="T_10c1f_row6_col0" class="data row6 col0" >1025.600000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row7" class="row_heading level0 row7" >Zack Snyder</th>
#       <td id="T_10c1f_row7_col0" class="data row7 col0" >975.740000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row8" class="row_heading level0 row8" >Peter Jackson</th>
#       <td id="T_10c1f_row8_col0" class="data row8 col0" >860.450000</td>
#     </tr>
#     <tr>
#       <th id="T_10c1f_level0_row9" class="row_heading level0 row9" >Justin Lin</th>
#       <td id="T_10c1f_row9_col0" class="data row9 col0" >824.790000</td>
#     </tr>
#   </tbody>
# </table>

# %%
box.to_csv(r'./Total_Revenue.csv')## sauvgearder le résutat sur un fishier csv

# %% [markdown]
# ## Q4: Création d'un graphique avec la moyenne des notes (colonne `rating`) des films en ordonnée et leur année en abscisse

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
film = df.groupby(['Title',"Year"])['Rating'].mean().to_frame().sort_values("Rating", ascending=False )# notre résultat ordonné par note
film.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_d7b0c_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d7b0c_row1_col0 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_d7b0c_row2_col0, #T_d7b0c_row3_col0, #T_d7b0c_row4_col0 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_d7b0c_row5_col0, #T_d7b0c_row6_col0, #T_d7b0c_row7_col0, #T_d7b0c_row8_col0, #T_d7b0c_row9_col0, #T_d7b0c_row10_col0 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_d7b0c_row11_col0, #T_d7b0c_row12_col0 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_d7b0c_row13_col0, #T_d7b0c_row14_col0, #T_d7b0c_row15_col0, #T_d7b0c_row16_col0, #T_d7b0c_row17_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_d7b0c_row18_col0, #T_d7b0c_row19_col0, #T_d7b0c_row20_col0, #T_d7b0c_row21_col0, #T_d7b0c_row22_col0, #T_d7b0c_row23_col0, #T_d7b0c_row24_col0, #T_d7b0c_row25_col0, #T_d7b0c_row26_col0 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_d7b0c_row27_col0, #T_d7b0c_row28_col0, #T_d7b0c_row29_col0, #T_d7b0c_row30_col0, #T_d7b0c_row31_col0, #T_d7b0c_row32_col0, #T_d7b0c_row33_col0, #T_d7b0c_row34_col0, #T_d7b0c_row35_col0, #T_d7b0c_row36_col0, #T_d7b0c_row37_col0, #T_d7b0c_row38_col0, #T_d7b0c_row39_col0, #T_d7b0c_row40_col0, #T_d7b0c_row41_col0, #T_d7b0c_row42_col0, #T_d7b0c_row43_col0, #T_d7b0c_row44_col0, #T_d7b0c_row45_col0, #T_d7b0c_row46_col0, #T_d7b0c_row47_col0, #T_d7b0c_row48_col0, #T_d7b0c_row49_col0, #T_d7b0c_row50_col0 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_d7b0c_row51_col0, #T_d7b0c_row52_col0, #T_d7b0c_row53_col0, #T_d7b0c_row54_col0, #T_d7b0c_row55_col0, #T_d7b0c_row56_col0, #T_d7b0c_row57_col0, #T_d7b0c_row58_col0, #T_d7b0c_row59_col0, #T_d7b0c_row60_col0, #T_d7b0c_row61_col0, #T_d7b0c_row62_col0, #T_d7b0c_row63_col0, #T_d7b0c_row64_col0, #T_d7b0c_row65_col0, #T_d7b0c_row66_col0, #T_d7b0c_row67_col0, #T_d7b0c_row68_col0, #T_d7b0c_row69_col0 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_d7b0c_row70_col0, #T_d7b0c_row71_col0, #T_d7b0c_row72_col0, #T_d7b0c_row73_col0, #T_d7b0c_row74_col0, #T_d7b0c_row75_col0, #T_d7b0c_row76_col0, #T_d7b0c_row77_col0, #T_d7b0c_row78_col0, #T_d7b0c_row79_col0, #T_d7b0c_row80_col0, #T_d7b0c_row81_col0, #T_d7b0c_row82_col0, #T_d7b0c_row83_col0, #T_d7b0c_row84_col0, #T_d7b0c_row85_col0, #T_d7b0c_row86_col0, #T_d7b0c_row87_col0, #T_d7b0c_row88_col0, #T_d7b0c_row89_col0 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_d7b0c_row90_col0, #T_d7b0c_row91_col0, #T_d7b0c_row92_col0, #T_d7b0c_row93_col0, #T_d7b0c_row94_col0, #T_d7b0c_row95_col0, #T_d7b0c_row96_col0, #T_d7b0c_row97_col0, #T_d7b0c_row98_col0, #T_d7b0c_row99_col0, #T_d7b0c_row100_col0, #T_d7b0c_row101_col0, #T_d7b0c_row102_col0, #T_d7b0c_row103_col0, #T_d7b0c_row104_col0, #T_d7b0c_row105_col0, #T_d7b0c_row106_col0, #T_d7b0c_row107_col0, #T_d7b0c_row108_col0, #T_d7b0c_row109_col0, #T_d7b0c_row110_col0, #T_d7b0c_row111_col0, #T_d7b0c_row112_col0, #T_d7b0c_row113_col0, #T_d7b0c_row114_col0, #T_d7b0c_row115_col0, #T_d7b0c_row116_col0, #T_d7b0c_row117_col0, #T_d7b0c_row118_col0, #T_d7b0c_row119_col0, #T_d7b0c_row120_col0, #T_d7b0c_row121_col0, #T_d7b0c_row122_col0, #T_d7b0c_row123_col0, #T_d7b0c_row124_col0, #T_d7b0c_row125_col0, #T_d7b0c_row126_col0, #T_d7b0c_row127_col0 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_d7b0c_row128_col0, #T_d7b0c_row129_col0, #T_d7b0c_row130_col0, #T_d7b0c_row131_col0, #T_d7b0c_row132_col0, #T_d7b0c_row133_col0, #T_d7b0c_row134_col0, #T_d7b0c_row135_col0, #T_d7b0c_row136_col0, #T_d7b0c_row137_col0, #T_d7b0c_row138_col0, #T_d7b0c_row139_col0, #T_d7b0c_row140_col0, #T_d7b0c_row141_col0, #T_d7b0c_row142_col0, #T_d7b0c_row143_col0, #T_d7b0c_row144_col0, #T_d7b0c_row145_col0, #T_d7b0c_row146_col0, #T_d7b0c_row147_col0, #T_d7b0c_row148_col0, #T_d7b0c_row149_col0, #T_d7b0c_row150_col0, #T_d7b0c_row151_col0, #T_d7b0c_row152_col0 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_d7b0c_row153_col0, #T_d7b0c_row154_col0, #T_d7b0c_row155_col0, #T_d7b0c_row156_col0, #T_d7b0c_row157_col0, #T_d7b0c_row158_col0, #T_d7b0c_row159_col0, #T_d7b0c_row160_col0, #T_d7b0c_row161_col0, #T_d7b0c_row162_col0, #T_d7b0c_row163_col0, #T_d7b0c_row164_col0, #T_d7b0c_row165_col0, #T_d7b0c_row166_col0, #T_d7b0c_row167_col0, #T_d7b0c_row168_col0, #T_d7b0c_row169_col0, #T_d7b0c_row170_col0, #T_d7b0c_row171_col0, #T_d7b0c_row172_col0, #T_d7b0c_row173_col0, #T_d7b0c_row174_col0, #T_d7b0c_row175_col0, #T_d7b0c_row176_col0, #T_d7b0c_row177_col0, #T_d7b0c_row178_col0 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_d7b0c_row179_col0, #T_d7b0c_row180_col0, #T_d7b0c_row181_col0, #T_d7b0c_row182_col0, #T_d7b0c_row183_col0, #T_d7b0c_row184_col0, #T_d7b0c_row185_col0, #T_d7b0c_row186_col0, #T_d7b0c_row187_col0, #T_d7b0c_row188_col0, #T_d7b0c_row189_col0, #T_d7b0c_row190_col0, #T_d7b0c_row191_col0, #T_d7b0c_row192_col0, #T_d7b0c_row193_col0, #T_d7b0c_row194_col0, #T_d7b0c_row195_col0, #T_d7b0c_row196_col0, #T_d7b0c_row197_col0, #T_d7b0c_row198_col0, #T_d7b0c_row199_col0, #T_d7b0c_row200_col0, #T_d7b0c_row201_col0, #T_d7b0c_row202_col0, #T_d7b0c_row203_col0, #T_d7b0c_row204_col0, #T_d7b0c_row205_col0, #T_d7b0c_row206_col0, #T_d7b0c_row207_col0, #T_d7b0c_row208_col0, #T_d7b0c_row209_col0, #T_d7b0c_row210_col0, #T_d7b0c_row211_col0 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_d7b0c_row212_col0, #T_d7b0c_row213_col0, #T_d7b0c_row214_col0, #T_d7b0c_row215_col0, #T_d7b0c_row216_col0, #T_d7b0c_row217_col0, #T_d7b0c_row218_col0, #T_d7b0c_row219_col0, #T_d7b0c_row220_col0, #T_d7b0c_row221_col0, #T_d7b0c_row222_col0, #T_d7b0c_row223_col0, #T_d7b0c_row224_col0, #T_d7b0c_row225_col0, #T_d7b0c_row226_col0, #T_d7b0c_row227_col0, #T_d7b0c_row228_col0, #T_d7b0c_row229_col0, #T_d7b0c_row230_col0, #T_d7b0c_row231_col0, #T_d7b0c_row232_col0, #T_d7b0c_row233_col0, #T_d7b0c_row234_col0, #T_d7b0c_row235_col0, #T_d7b0c_row236_col0, #T_d7b0c_row237_col0, #T_d7b0c_row238_col0, #T_d7b0c_row239_col0, #T_d7b0c_row240_col0 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_d7b0c_row241_col0, #T_d7b0c_row242_col0, #T_d7b0c_row243_col0, #T_d7b0c_row244_col0, #T_d7b0c_row245_col0, #T_d7b0c_row246_col0, #T_d7b0c_row247_col0, #T_d7b0c_row248_col0, #T_d7b0c_row249_col0, #T_d7b0c_row250_col0, #T_d7b0c_row251_col0, #T_d7b0c_row252_col0, #T_d7b0c_row253_col0, #T_d7b0c_row254_col0, #T_d7b0c_row255_col0, #T_d7b0c_row256_col0, #T_d7b0c_row257_col0, #T_d7b0c_row258_col0, #T_d7b0c_row259_col0, #T_d7b0c_row260_col0, #T_d7b0c_row261_col0, #T_d7b0c_row262_col0, #T_d7b0c_row263_col0, #T_d7b0c_row264_col0, #T_d7b0c_row265_col0, #T_d7b0c_row266_col0, #T_d7b0c_row267_col0, #T_d7b0c_row268_col0, #T_d7b0c_row269_col0, #T_d7b0c_row270_col0, #T_d7b0c_row271_col0, #T_d7b0c_row272_col0, #T_d7b0c_row273_col0, #T_d7b0c_row274_col0, #T_d7b0c_row275_col0, #T_d7b0c_row276_col0, #T_d7b0c_row277_col0 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_d7b0c_row278_col0, #T_d7b0c_row279_col0, #T_d7b0c_row280_col0, #T_d7b0c_row281_col0, #T_d7b0c_row282_col0, #T_d7b0c_row283_col0, #T_d7b0c_row284_col0, #T_d7b0c_row285_col0, #T_d7b0c_row286_col0, #T_d7b0c_row287_col0, #T_d7b0c_row288_col0, #T_d7b0c_row289_col0, #T_d7b0c_row290_col0, #T_d7b0c_row291_col0, #T_d7b0c_row292_col0, #T_d7b0c_row293_col0, #T_d7b0c_row294_col0, #T_d7b0c_row295_col0, #T_d7b0c_row296_col0, #T_d7b0c_row297_col0, #T_d7b0c_row298_col0, #T_d7b0c_row299_col0, #T_d7b0c_row300_col0, #T_d7b0c_row301_col0, #T_d7b0c_row302_col0, #T_d7b0c_row303_col0, #T_d7b0c_row304_col0, #T_d7b0c_row305_col0, #T_d7b0c_row306_col0, #T_d7b0c_row307_col0, #T_d7b0c_row308_col0, #T_d7b0c_row309_col0, #T_d7b0c_row310_col0, #T_d7b0c_row311_col0, #T_d7b0c_row312_col0, #T_d7b0c_row313_col0, #T_d7b0c_row314_col0, #T_d7b0c_row315_col0 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_d7b0c_row316_col0, #T_d7b0c_row317_col0, #T_d7b0c_row318_col0, #T_d7b0c_row319_col0, #T_d7b0c_row320_col0, #T_d7b0c_row321_col0, #T_d7b0c_row322_col0, #T_d7b0c_row323_col0, #T_d7b0c_row324_col0, #T_d7b0c_row325_col0, #T_d7b0c_row326_col0, #T_d7b0c_row327_col0, #T_d7b0c_row328_col0

# %%
film = film.reset_index()
film
# Out:
#                         Title  Year  Rating
# 0             The Dark Knight  2008     9.0
# 1                   Inception  2010     8.8
# 2               Kimi no na wa  2016     8.6
# 3            The Intouchables  2011     8.6
# 4                Interstellar  2014     8.6
# ..                        ...   ...     ...
# 833      2307: Winter's Dream  2016     4.0
# 834  The Disappointments Room  2016     3.9
# 835       Birth of the Dragon  2016     3.9
# 836      Dragonball Evolution  2009     2.7
# 837            Disaster Movie  2008     1.9
#
# [838 rows x 3 columns]

# %%
film = film.sort_values(by=['Title'])## ordonner les film par ordre alphabétique
film
# Out:
#                     Title  Year  Rating
# 148  (500) Days of Summer  2009     7.7
# 283   10 Cloverfield Lane  2016     7.2
# 45       12 Years a Slave  2013     8.1
# 171             127 Hours  2010     7.6
# 268              13 Hours  2016     7.3
# ..                    ...   ...     ...
# 236      Zero Dark Thirty  2012     7.4
# 139                Zodiac  2007     7.7
# 134            Zombieland  2009     7.7
# 824           Zoolander 2  2016     4.7
# 44               Zootopia  2016     8.1
#
# [838 rows x 3 columns]

# %% [markdown]
# ## Seaborn Violin Plot

# %% [markdown]
# Violin plots are used to visualize data distributions, displaying the range, median, and distribution of the data.

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(20.7, 7.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

swarm_plot = sns.violinplot(data=film, x='Year', y='Rating')
swarm_plot.set_title("Rating by year")
fig = swarm_plot.get_figure()
fig.savefig("IMDB_Plot1.jpeg") # sauvegarder le graphe en image JPEG

# %% [markdown]
# <div class="alert alert-success">
#   <p><strong> La plage, la médiane et distribution des notes par an. </strong></p>
# </div>

# %%
import plotly
import chart_studio.plotly as py

import plotly.express as px
import plotly.graph_objects as go
plt.rcParams['figure.figsize']=17,8
import cufflinks as cf

import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
film_iplot = film.iplot(kind='scatter',x='Year',y='Rating',mode='markers',title='La moyenne de note des film par an : ',xTitle='Année',yTitle='Note',color="blue",size=5)
# Out:
# <div>                            <div id="cde924ec-4a20-4d5f-94bd-23cb4358b00c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("cde924ec-4a20-4d5f-94bd-23cb4358b00c")) {                    Plotly.newPlot(                        "cde924ec-4a20-4d5f-94bd-23cb4358b00c",                        [{"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 5, "symbol": "circle"}, "mode": "markers", "name": "Rating", "text": "", "type": "scatter", "x": [2009, 2016, 2013, 2010, 2016, 2007, 2009, 2009, 2016, 2008, 2012, 2014, 2016, 2007, 2014, 2009, 2006, 2014, 2016, 2013, 2011, 2015, 2016, 2006, 2016, 2016, 2014, 2016, 2016, 2016, 2016, 2014, 2013, 2007, 2013, 2013, 2016, 2014, 2016, 2010, 2007, 2010, 2016, 2016, 2007, 2016, 2013, 2012, 2014, 2012, 2014, 2014, 2015, 2016, 2009, 2006, 2012, 2016, 2016, 2007, 2008, 2009, 2015, 2006, 2016, 2016, 2016, 2016, 2016, 2012, 2013, 2014, 2013, 2016, 2007, 2014, 2016, 2014, 2016, 2015, 2010, 2015, 2016, 2016, 2014, 2006, 2016, 2013, 2010, 2008, 2015, 2016, 2014, 2012, 2009, 2011, 2015, 2007, 2016, 2015, 2015, 2016, 2016, 2016, 2011, 2014, 
 2016, 2011, 2012, 2015, 2014, 2010, 2006, 2010, 2012, 2016, 2008, 2013, 2011, 2011, 2010, 2014, 2016, 2012, 2008, 2006, 2016, 2015, 2013, 2013, 2010, 2015, 2016, 2012, 2013, 2010, 2015, 2011, 2015, 2008, 2012, 2014, 2014, 2008, 2010, 2011, 2010, 2006, 2009, 2011, 2016, 2007, 2010, 2015, 2016, 2012, 2014, 2016, 2016, 2012, 2015, 2012, 2015, 2016, 2006, 2008, 2006, 2012, 2016, 2013, 2011, 2015, 2015, 2007, 2016, 2015, 2012, 2015, 2010, 2009, 2016, 2013, 2015, 2007, 2008, 2006, 2008, 2015, 2016, 2015, 2011, 2016, 2016, 2007, 2010, 2011, 2007, 2006, 2007, 2016, 2007, 2008, 2014, 2006, 2 ...

# %% [markdown]
# ## Q5. Déterminer les paramètres les plus impactants sur le score (colonne `rating`).

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %% [markdown]
# ### La matrice de corrélation:

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder

# %%
corr_df = df.corr(method='pearson')
print("The correlation DataFrame is:")
# print(corr_df, "\n")
plt.figure(figsize=(8, 6))
sns.heatmap(corr_df, annot=True)
plt.show()

corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# The correlation DataFrame is:
# <style type="text/css">
# #T_e2836_row0_col0, #T_e2836_row1_col1, #T_e2836_row2_col2, #T_e2836_row3_col3, #T_e2836_row4_col4, #T_e2836_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e2836_row0_col1, #T_e2836_row0_col2, #T_e2836_row0_col3, #T_e2836_row0_col4, #T_e2836_row0_col5, #T_e2836_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e2836_row1_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e2836_row1_col2, #T_e2836_row3_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e2836_row1_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_e2836_row1_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_e2836_row1_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e2836_row2_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e2836_row2_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e2836_row2_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_e2836_row2_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e2836_row2_col5 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_e2836_row3_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_e2836_row3_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_e2836_row3_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e2836_row4_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e2836_row4_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e2836_row4_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e2836_row4_col3 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_e2836_row4_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e2836_row5_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e2836_row5_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e2836_row5_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_e2836_row5_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_e2836_row5_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# </style>
# <table id="T_e2836_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >Runtime (Minutes)</th>
#       <th class="col_heading level0 col2" >Rating</th>
#       <th class="col_heading level0 col3" >Votes</th>
#       <th class="col_heading level0 col4" >Revenue (Millions)</th>
#       <th class="col_heading level0 col5" >Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2836_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_e2836_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e2836_row0_col1" class="data row0 col1" >-0.101933</td>
#       <td id="T_e2836_row0_col2" class="data row0 col2" >-0.145703</td>
#       <td id="T_e2836_row0_col3" class="data row0 col3" >-0.362445</td>
#       <td id="T_e2836_row0_col4" class="data row0 col4" >-0.129198</td>
#       <td id="T_e2836_row0_col5" class="data row0 col5" >-0.062303</td>
#     </tr>
#     <tr>
#       <th id="T_e2836_level0_row1" class="row_heading level0 row1" >Runtime (Minutes)</th>
#       <td id="T_e2836_row1_col0" class="data row1 col0" >-0.101933</td>
#       <td id="T_e2836_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e2836_row1_col2" class="data row1 col2" >0.374566</td>
#       <td id="T_e2836_row1_col3" class="data row1 col3" >0.399298</td>
#       <td id="T_e2836_row1_col4" class="data row1 col4" >0.281721</td>
#       <td id="T_e2836_row1_col5" class="data row1 col5" >0.221397</td>
#     </tr>
#     <tr>
#       <th id="T_e2836_level0_row2" class="row_heading level0 row2" >Rating</th>
#       <td id="T_e2836_row2_col0" class="data row2 col0" >-0.145703</td>
#       <td id="T_e2836_row2_col1" class="data row2 col1" >0.374566</td>
#       <td id="T_e2836_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e2836_row2_col3" class="data row2 col3" >0.517452</td>
#       <td id="T_e2836_row2_col4" class="data row2 col4" >0.217106</td>
#       <td id="T_e2836_row2_col5" class="data row2 col5" >0.672731</td>
#     </tr>
#     <tr>
#       <th id="T_e2836_level0_row3" class="row_heading level0 row3" >Votes</th>
#       <td id="T_e2836_row3_col0" class="data row3 col0" >-0.362445</td>
#       <td id="T_e2836_row3_col1" class="data row3 col1" >0.399298</td>
#       <td id="T_e2836_row3_col2" class="data row3 col2" >0.517452</td>
#       <td id="T_e2836_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e2836_row3_col4" class="data row3 col4" >0.636833</td>
#       <td id="T_e2836_row3_col5" class="data row3 col5" >0.332674</td>
#     </tr>
#     <tr>
#       <th id="T_e2836_level0_row4" class="row_heading level0 row4" >Revenue (Millions)</th>
#       <td id="T_e2836_row4_col0" class="data row4 col0" >-0.129198</td>
#       <td id="T_e2836_row4_col1" class="data row4 col1" >0.281721</td>
#       <td id="T_e2836_row4_col2" class="data row4 col2" >0.217106</td>
#       <td id="T_e2836_row4_col3" class="data row4 col3" >0.636833</td>
#       <td id="T_e2836_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_e2836_row4_col5" class="data row4 col5" >0.142397</td>
#     </tr>
#     <tr>
#       <th id="T_e2836_level0_row5" class="row_heading level0 row5" >Metascore</th>
#       <td id="T_e2836_row5_col0" class="data row5 col0" >-0.062303</td>
#       <td id="T_e2836_row5_col1" class="data row5 col1" >0.221397</td>
#       <td id="T_e2836_row5_col2" class="data row5 col2" >0.672731</td>
#       <td id="T_e2836_row5_col3" class="data row5 col3" >0.332674</td>
#       <td id="T_e2836_row5_col4" class="data row5 col4" >0.142397</td>
#       <td id="T_e2836_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-success">
#   <p><strong>A partir de la matrice corréler on deduit que les paramétres les plus impactant sont le Metascore en premier à 0.67 et les votes en deuxiéme à 0.51.   </strong></p>
# </div

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#l'impacte du metascore sur le score
sns.set_style("darkgrid")
sns.lmplot(data= df, y = "Metascore", x = "Rating", height = 10)
plt.title("Rate vs Metascore", fontsize = 13)
plt.show()

# %%
#l'impacte des votes sur le score
sns.set_style("darkgrid")
sns.lmplot(data= df, y = "Votes", x = "Rating", height = 10)
plt.title("Rate vs Votes", fontsize = 13)
plt.show()

# %%
#l'impacte de la durée de film sur le score
sns.set_style("darkgrid")
sns.lmplot(data= df, y = "Runtime (Minutes)", x = "Rating", height = 10)
plt.title("Rate vs Runtime", fontsize = 13)
plt.show()

# %%
#l'impacte du Revenue sur le score
sns.set_style("darkgrid")
sns.lmplot(data= df, y = "Revenue (Millions)", x = "Rating", height = 10)
plt.title("Rate vs Revenue", fontsize = 13)
plt.show()

# %% [markdown]
# ## Q3. Création d'une nouvelle colonne incluant les revenus en dollars constant à l'aide des données d'inflation de l'OCDE.

# %%
inf = pd.read_csv(r"./DF_OCDE.csv")#importation de données
inf
# Out:
#      LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME       Value  \
# 0         AUS       CPI     TOT  IDX2015         A  1949    3.738101
# 1         AUS       CPI     TOT  IDX2015         A  1950    4.063153
# 2         AUS       CPI     TOT  IDX2015         A  1951    4.852566
# 3         AUS       CPI     TOT  IDX2015         A  1952    5.688414
# 4         AUS       CPI     TOT  IDX2015         A  1953    5.943812
# ...       ...       ...     ...      ...       ...   ...         ...
# 2250     OECD       CPI     TOT  IDX2015         A  2016  101.197500
# 2251     OECD       CPI     TOT  IDX2015         A  2017  103.506100
# 2252     OECD       CPI     TOT  IDX2015         A  2018  106.204400
# 2253     OECD       CPI     TOT  IDX2015         A  2019  108.401300
# 2254     OECD       CPI     TOT  IDX2015         A  2020  109.884500
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2250        NaN
# 2251        NaN
# 2252        NaN
# 2253        NaN
# 2254        NaN
#
# [2255 rows x 8 columns]

# %%
inf.isnull().mean()
# Out:
# LOCATION      0.000000
# INDICATOR     0.000000
# SUBJECT       0.000000
# MEASURE       0.000000
# FREQUENCY     0.000000
# TIME          0.000000
# Value         0.000000
# Flag Codes    0.999557
# dtype: float64

# %%
inf.shape
# Out:
# (2255, 8)

# %%
inf = inf.drop('Flag Codes', axis='columns')#supression la colonne flag codes

# %%
inf.isnull().mean()
# Out:
# LOCATION     0.0
# INDICATOR    0.0
# SUBJECT      0.0
# MEASURE      0.0
# FREQUENCY    0.0
# TIME         0.0
# Value        0.0
# dtype: float64

# %%
inf.shape
# Out:
# (2255, 7)

# %%
NewInf = inf[inf["LOCATION"] == "USA"]#prendre les valeurs de la USA puisque les revenues sont en dollard 
NewInf = NewInf.rename(columns={'TIME': 'Year'})#renomer la colonne pour la preparer au merge
NewInf
# Out:
#      LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  Year      Value
# 1816      USA       CPI     TOT  IDX2015         A  1955   11.29666
# 1817      USA       CPI     TOT  IDX2015         A  1956   11.46894
# 1818      USA       CPI     TOT  IDX2015         A  1957   11.85217
# 1819      USA       CPI     TOT  IDX2015         A  1958   12.17564
# 1820      USA       CPI     TOT  IDX2015         A  1959   12.29870
# ...       ...       ...     ...      ...       ...   ...        ...
# 1877      USA       CPI     TOT  IDX2015         A  2016  101.26160
# 1878      USA       CPI     TOT  IDX2015         A  2017  103.41860
# 1879      USA       CPI     TOT  IDX2015         A  2018  105.94460
# 1880      USA       CPI     TOT  IDX2015         A  2019  107.86460
# 1881      USA       CPI     TOT  IDX2015         A  2020  109.19520
#
# [66 rows x 7 columns]

# %%
newData = df

# %%
#joindre les deux df (inner joint) en prenant que les colonnes nécessaire
newData = newData.merge(NewInf[["Value","Year"]], on="Year", how='inner')
newData
# Out:
#                             Title                    Genre  \
# 0         Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 1                    Interstellar   Adventure,Drama,Sci-Fi
# 2                       John Wick    Action,Crime,Thriller
# 3    Kingsman: The Secret Service  Action,Adventure,Comedy
# 4                       Gone Girl      Crime,Drama,Mystery
# ..                            ...                      ...
# 833                       Riddick   Action,Sci-Fi,Thriller
# 834                   After Earth  Action,Adventure,Sci-Fi
# 835           The Kings of Summer   Adventure,Comedy,Drama
# 836                        Trance      Crime,Drama,Mystery
# 837             Texas Chainsaw 3D          Horror,Thriller
#
#                                            Description             Director  \
# 0    A group of intergalactic criminals are forced ...           James Gunn
# 1    A team of explorers travel through a wormhole ...    Christopher Nolan
# 2    An ex-hitman comes out of retirement to track ...       Chad Stahelski
# 3    A spy organization recruits an unrefined, but ...       Matthew Vaughn
# 4    With his wife's disappearance having become th...        David Fincher
# ..                                                 ...                  ...
# 833  Left for dead on a sun-scorched planet, Riddic...          David Twohy
# 834  A crash landing leaves Kitai Raige and his fat...   M. Night Shyamalan
# 835  Three teenage friends, in the ultimate act of ...  Jordan Vogt-Roberts
# 836  An art auctioneer who has become mixed up with...          Danny Boyle
# 837  A young woman travels to Texas to collect an i...      John Luessenhop
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 2    Keanu Reeves, Michael Nyqvist, Alfie Allen, Wi...  2014
# 3    Colin Firth, Taron Egerton, Samuel L. Jackson,...  2014
# 4    Ben Affleck, Rosamund Pike, Neil Patrick Harri...  2014
# ..                                                 ...   ...
# 833  Vin Diesel, Karl Urban, Katee Sackhoff, Jordi ...  2013
# 834  Jaden Smith, David Denman, Will Smith,Sophie O...  2013
# 835  Nick Robinson, Gabriel Basso, Moises Arias,Nic...  2013
# 836  James McAvoy, Rosario Dawson, Vincent Cassel,D...  2013
# 837  Alexandra Daddario, Tania Raymonde, Scott East...  2013
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore  \
# 0                  121     8.1   757074              333.13       76.0
# 1                  169     8.6  1047747              187.99       74.0
# 2                  101     7.2   321933               43.00       68.0
# 3                  129     7.7   440209              128.25       58.0
# 4                  149     8.1   636243              167.74       79.0
# ..                 ...     ...      ...                 ...        ...
# 833                119     6.4   132098               42.00       49.0
# 834                100     4.9   166512               60.52       33.0
# 835                 95     7.2    65653                1.29       61.0
# 836                101     7.0    97141                2.32       61.0
# 837                 92     4.8    37060               34.33       62.0
#
#         Value
# 0    99.88152
# 1    99.88152
# 2    99.88152
# 3    99.88152
# 4    99.88152
# ..        ...
# 833  98.28708
# 834  98.28708
# 835  98.28708
# 836  98.28708
# 837  98.28708
#
# [838 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-danger">
#   <h1><strong> Fin </strong></h1>
# </div>
